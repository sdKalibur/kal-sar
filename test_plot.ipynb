# %%
import matplotlib.pyplot as plt

# %matplotlib inline

x = list(range(0,10))
y = list(range(-10,0))

         
plt.plot(x,y)

# %%
a = [0,-100,25,67,-50]
b = [0,3,10,45,80]
plt.title("Weird Graph")
plt.plot(a,b)

# %%
a = [0,5,10,2,4,8,3,3]
b = [0,5, 0,0,4,0,2,5]
plt.plot(a,b)
